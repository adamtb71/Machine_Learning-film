# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os

# %%
#Version of the graph for our perposes
movies_df = pd.read_csv('Movie_budget_and_revenue_v3.csv')
movies_df.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                     title.1     budget     revenue   RB Ratio  \
# 0                                    Avatar  237000000  2787965087  11.763566
# 1  Pirates of the Caribbean: At World's End  300000000   961000000   3.203333
# 2                                   Spectre  245000000   880674609   3.594590
# 3                     The Dark Knight Rises  250000000  1084939099   4.339756
# 4                               John Carter  260000000   284139100   1.092843
#
#    RT Score
# 0      0.82
# 1      0.44
# 2      0.63
# 3      0.87
# 4      0.52

# %%
import requests

url = "http://www.omdbapi.com/?apikey=trilogy&t="
movies = movies_df['title'].values.tolist() 
movie_name = []
plot =[]
i=1
#run through the api
for movie in movies:
    try:
        movie_data = requests.get(url + movie).json()
        movie_name.append(movie_data['Title'])
        plot.append(movie_data['Plot'])
        #rotten_tomatoes.append(get_tomato(movie_data))
        #metascore.append(movie_data['Metascore'])
        #imdb_rating.append(movie_data['imdbRating'])
        print(f"Processsing record {i} | {movie}" )
        i=i+1
    except Exception:
        print("error")
# Out:
# Processsing record 1 | Avatar
# Processsing record 2 | Pirates of the Caribbean: At World's End
# Processsing record 3 | Spectre
# Processsing record 4 | The Dark Knight Rises
# Processsing record 5 | John Carter
# Processsing record 6 | Spider-Man 3
# Processsing record 7 | Tangled
# Processsing record 8 | Avengers: Age of Ultron
# Processsing record 9 | Harry Potter and the Half-Blood Prince
# Processsing record 10 | Batman v Superman: Dawn of Justice
# Processsing record 11 | Superman Returns
# Processsing record 12 | Quantum of Solace
# Processsing record 13 | Pirates of the Caribbean: Dead Man's Chest
# Processsing record 14 | The Lone Ranger
# Processsing record 15 | Man of Steel
# Processsing record 16 | The Chronicles of Narnia: Prince Caspian
# Processsing record 17 | The Avengers
# Processsing record 18 | Pirates of the Caribbean: On Stranger Tides
# Processsing record 19 | Men in Black 3
# Processsing record 20 | The Hobbit: The Battle of the Five Armies
# Processsing record 21 | The Amazing Spider-Man
# Processsing record 22 | Robin Hood
# Processsing record 23 | The Hobbit: The Desolation of Smaug
# Processsing record 24 | The Golden Compass
# Processsing record 25 | King Kong
# Processsing record 26 | Titanic
# Processsing record 27 | Captain America: Civil War
# Processsing record 28 | Battleship
# Processsing record 29 | Jurassic World
# Processsing record 30 | Skyfall
# Processsing record 31 | Spider-Man 2
# Processsing record 32 | Iron Man 3
# Processsing record 33 | Alice in Wonderland
# Processsing record 34 | X-Men: The Last Stand
# Processsing record 35 | Monsters University
# Processsing record 36 | Transformers: Revenge of the Fallen
# Processsing record 37 | Transformers: Age of Extinction
# Processsing record 38 | Oz: The Great and Powerful
# Processsing record 39 | The Amazing Spider-Man 2
# Processsing record 40 | TRON: Legacy
# Processsing record 41 | Cars 2
# Processsing record 42 | Green Lantern
# Processsing record 43 | Toy Story 3
# Processsing record 44 | Terminator Salvation
# Processsing record 45 | Furious 7
# Processsing record 46 | World War Z
# Processsing record 47 | X-Men: Days of Future Past
# Processsing record 48 | Star Trek Into Darkness
# Processsing record 49 | Jack the Giant Slayer
# Processsing record 50 | The Great Gatsby
# Processsing record 51 | Prince of Persia: The Sands of Time
# Processsing record 52 | Pacific Rim
# Processsing record 53 | Transformers: Dark of the Moon
# Processsing record 54 | Indiana Jones and the Kingdom of the Crystal Skull
# Processsing record 55 | The Good Dinosaur
# Processsing record 56 | Brave
# Processsing record 57 | Star Trek Beyond
# Processsing record 58 | Rush Hour 3
# Processsing record 59 | 2012
# Processsing record 60 | A Christmas Carol
# Processsing record 61 | Jupiter Ascending
# Processsing record 62 | The Legend of Tarzan
# Processsing record 63 | The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Processsing record 64 | X-Men: Apocalypse
# Processsing record 65 | The Dark Knight
# Processsing record 66 | Up
# Processsing record 67 | Iron Man
# Processsing record 68 | Hugo
# Processsing record 69 | Wild Wild West
# Processsing record 70 | The Mummy: Tomb of the Dragon Emperor
# Processsing record 71 | Suicide Squad
# Processsing record 72 | Evan Almighty
# Processsing record 73 | Edge of Tomorrow
# Processsing record 74 | Waterworld
# Processsing record 75 | G.I. Joe: The Rise of Cobra
# Processsing record 76 | Inside Out
# Processsing record 77 | The Jungle Book
# Processsing record 78 | Iron Man 2
# Processsing record 79 | Snow White and the Huntsman
# Processsing record 80 | Maleficent
# Processsing record 81 | Dawn of the Planet of the Apes
# Processsing record 82 | 47 Ronin
# Processsing record 83 | Captain America: The Winter Soldier
# Processsing record 84 | Shrek Forever After
# Processsing record 85 | Tomorrowland
# Processsing record 86 | Big Hero 6
# Processsing record 87 | Wreck-It Ralph
# Processsing record 88 | The Polar Express
# Processsing record 89 | Independence Day: Resurgence
# Processsing record 90 | How to Train Your Dragon
# Processsing record 91 | Terminator 3: Rise of the Machines
# Processsing record 92 | Guardians of the Galaxy
# Processsing record 93 | Interstellar
# Processsing record 94 | Inception
# Processsing record 95 | Shin Godzilla
# Processsing record 96 | The Hobbit: An Unexpected Journey
# Processsing record 97 | The Fast and the Furious
# Processsing record 98 | The Curious Case of Benjamin Button
# Processsing record 99 | X-Men: First Class
# Processsing record 100 | The Hunger Games: Mockingjay - Part 2
# Processsing record 101 | The Sorcerer's Apprentice
# Processsing record 102 | Poseidon
# Processsing record 103 | Alice Through the Looking Glass
# Processsing record 104 | Shrek the Third
# Processsing record 105 | Warcraft
# Processsing record 106 | Terminator Genisys
# Processsing record 107 | The Chronicles of Narnia: The Voyage of the Dawn Treader
# Processsing record 108 | Pearl Harbor
# Processsing record 109 | Transformers
# Processsing record 110 | Alexander
# Processsing record 111 | Harry Potter and the Order of the Phoenix
# Processsing record 112 | Harry Potter and the Goblet of Fire
# Processsing record 113 | Hancock
# Processsing record 114 | I Am Legend
# Processsing record 115 | Charlie and the Chocolate Factory
# Processsing record 116 | Ratatouille
# Processsing record 117 | Batman Begins
# Processsing record 118 | Madagascar: Escape 2 Africa
# Processsing record 119 | Night at the Museum: Battle of the Smithsonian
# Processsing record 120 | X-Men Origins: Wolverine
# Processsing record 121 | The Matrix Revolutions
# Processsing record 122 | Frozen
# Processsing record 123 | The Matrix Reloaded
# Processsing record 124 | Thor: The Dark World
# Processsing record 125 | Mad Max: Fury Road
# Processsing record 126 | Angels & Demons
# Processsing record 127 | Thor
# Processsing record 128 | Bolt
# Processsing record 129 | G-Force
# Processsing record 130 | Wrath of the Titans
# Processsing record 131 | Dark Shadows
# Processsing record 132 | Mission: Impossible - Rogue Nation
# Processsing record 133 | Bee Movie
# Processsing record 134 | Kung Fu Panda 2
# Processsing record 135 | The Last Airbender
# Processsing record 136 | Mission: Impossible III
# Processsing record 137 | White House Down
# Processsing record 138 | Mars Needs Moms
# Processsing record 139 | Flushed Away
# Processsing record 140 | Pan
# Processsing record 141 | Mr. Peabody & Sherman
# Processsing record 142 | Troy
# Processsing record 143 | Madagascar 3: Europe's Most Wanted
# Processsing record 144 | Die Another Day
# Processsing record 145 | Ghostbusters
# Processsing record 146 | Armageddon
# Processsing record 147 | Men in Black II
# Processsing record 148 | Beowulf
# Processsing record 149 | Kung Fu Panda 3
# Processsing record 150 | Mission: Impossible - Ghost Protocol
# Processsing record 151 | Rise of the Guardians
# Processsing record 152 | Fun with Dick and Jane
# Processsing record 153 | The Last Samurai
# Processsing record 154 | Exodus: Gods and Kings
# Processsing record 155 | Star Trek
# Processsing record 156 | Spider-Man
# Processsing record 157 | How to Train Your Dragon 2
# Processsing record 158 | Gods of Egypt
# Processsing record 159 | Stealth
# Processsing record 160 | Watchmen
# Processsing record 161 | Lethal Weapon 4
# Processsing record 162 | Hulk
# Processsing record 163 | G.I. Joe: Retaliation
# Processsing record 164 | Sahara
# Processsing record 165 | Final Fantasy: The Spirits Within
# Processsing record 166 | Captain America: The First Avenger
# Processsing record 167 | The World Is Not Enough
# Processsing record 168 | Master and Commander: The Far Side of the World
# Processsing record 169 | The Twilight Saga: Breaking Dawn - Part 2
# Processsing record 170 | Happy Feet Two
# Processsing record 171 | The Incredible Hulk
# Processsing record 172 | The BFG
# Processsing record 173 | The Revenant
# Processsing record 174 | Turbo
# Processsing record 175 | Rango
# Processsing record 176 | Penguins of Madagascar
# Processsing record 177 | The Bourne Ultimatum
# Processsing record 178 | Kung Fu Panda
# Processsing record 179 | Ant-Man
# Processsing record 180 | The Hunger Games: Catching Fire
# Processsing record 181 | Home
# Processsing record 182 | War of the Worlds
# Processsing record 183 | Bad Boys II
# Processsing record 184 | Puss in Boots
# Processsing record 185 | Salt
# Processsing record 186 | Noah
# Processsing record 187 | The Adventures of Tintin
# Processsing record 188 | Harry Potter and the Prisoner of Azkaban
# Processsing record 189 | Australia
# Processsing record 190 | After Earth
# Processsing record 191 | Dinosaur
# Processsing record 192 | Night at the Museum: Secret of the Tomb
# Processsing record 193 | Megamind
# Processsing record 194 | R.I.P.D.
# Processsing record 195 | Pirates of the Caribbean: The Curse of the Black Pearl
# Processsing record 196 | The Hunger Games: Mockingjay - Part 1
# Processsing record 197 | The Da Vinci Code
# Processsing record 198 | Rio 2
# Processsing record 199 | X2
# Processsing record 200 | Fast Five
# Processsing record 201 | Sherlock Holmes: A Game of Shadows
# Processsing record 202 | Clash of the Titans
# Processsing record 203 | Total Recall
# Processsing record 204 | The 13th Warrior
# Processsing record 205 | The Bourne Legacy
# Processsing record 206 | Batman & Robin
# Processsing record 207 | How the Grinch Stole Christmas
# Processsing record 208 | The Day After Tomorrow
# Processsing record 209 | Fantastic 4: Rise of the Silver Surfer
# Processsing record 210 | Life of Pi
# Processsing record 211 | Ghost Rider
# Processsing record 212 | Jason Bourne
# Processsing record 213 | Charlie's Angels: Full Throttle
# Processsing record 214 | Prometheus
# Processsing record 215 | Stuart Little 2
# Processsing record 216 | Elysium
# Processsing record 217 | The Chronicles of Riddick
# Processsing record 218 | RoboCop
# Processsing record 219 | Speed Racer
# Processsing record 220 | How Do You Know
# Processsing record 221 | Knight and Day
# Processsing record 222 | Oblivion
# Processsing record 223 | Star Wars: Episode III - Revenge of the Sith
# Processsing record 224 | Star Wars: Episode II - Attack of the Clones
# Processsing record 225 | Monsters, Inc.
# Processsing record 226 | The Wolverine
# Processsing record 227 | Star Wars: Episode I - The Phantom Menace
# Processsing record 228 | The Croods
# Processsing record 229 | Windtalkers
# Processsing record 230 | The Huntsman: Winter's War
# Processsing record 231 | Teenage Mutant Ninja Turtles
# Processsing record 232 | Gravity
# Processsing record 233 | Dante's Peak
# Processsing record 234 | Teenage Mutant Ninja Turtles: Out of the Shadows
# Processsing record 235 | Fantastic Four
# Processsing record 236 | Night at the Museum
# Processsing record 237 | San Andreas
# Processsing record 238 | Tomorrow Never Dies
# Processsing record 239 | The Patriot
# Processsing record 240 | Ocean's Twelve
# Processsing record 241 | Mr. & Mrs. Smith
# Processsing record 242 | Insurgent
# Processsing record 243 | The Aviator
# Processsing record 244 | Gulliver's Travels
# Processsing record 245 | The Green Hornet
# Processsing record 246 | 300: Rise of an Empire
# Processsing record 247 | The Smurfs
# Processsing record 248 | Home on the Range
# Processsing record 249 | Allegiant
# Processsing record 250 | Real Steel
# Processsing record 251 | The Smurfs 2
# Processsing record 252 | Speed 2: Cruise Control
# Processsing record 253 | Ender's Game
# Processsing record 254 | Live Free or Die Hard
# Processsing record 255 | The Lord of the Rings: The Fellowship of the Ring
# Processsing record 256 | Around the World in 80 Days
# Processsing record 257 | Ali
# Processsing record 258 | Kingdom of Heaven
# Processsing record 259 | Stuart Little
# Processsing record 260 | The Princess and the Frog
# Processsing record 261 | The Martian
# Processsing record 262 | The Island
# Processsing record 263 | Town & Country
# Processsing record 264 | Gladiator
# Processsing record 265 | Minority Report
# Processsing record 266 | Harry Potter and the Chamber of Secrets
# Processsing record 267 | Casino Royale
# Processsing record 268 | Planet of the Apes
# Processsing record 269 | Terminator 2: Judgment Day
# Processsing record 270 | Public Enemies
# Processsing record 271 | American Gangster
# Processsing record 272 | True Lies
# Processsing record 273 | Little Fockers
# Processsing record 274 | The Other Guys
# Processsing record 275 | Eraser
# Processsing record 276 | Django Unchained
# Processsing record 277 | The Hunchback of Notre Dame
# Processsing record 278 | The Emperor's New Groove
# Processsing record 279 | The Expendables 2
# Processsing record 280 | National Treasure
# Processsing record 281 | Where the Wild Things Are
# Processsing record 282 | Epic
# Processsing record 283 | The Tourist
# Processsing record 284 | End of Days
# Processsing record 285 | Blood Diamond
# Processsing record 286 | The Wolf of Wall Street
# Processsing record 287 | Batman Forever
# Processsing record 288 | Starship Troopers
# Processsing record 289 | Cloud Atlas
# Processsing record 290 | Legend of the Guardians: The Owls of Ga'Hoole
# Processsing record 291 | Catwoman
# Processsing record 292 | Hercules
# Processsing record 293 | Treasure Planet
# Processsing record 294 | Land of the Lost
# Processsing record 295 | The Expendables 3
# Processsing record 296 | Point Break
# Processsing record 297 | In the Heart of the Sea
# Processsing record 298 | The Adventures of Pluto Nash
# Processsing record 299 | Green Zone
# Processsing record 300 | The Peanuts Movie
# Processsing record 301 | The Spanish Prisoner
# Processsing record 302 | The Mummy Returns
# Processsing record 303 | Gangs of New York
# Processsing record 304 | The Flowers of War
# Processsing record 305 | Surf's Up
# Processsing record 306 | The Stepford Wives
# Processsing record 307 | Black Hawk Down
# Processsing record 308 | The Fifth Element
# Processsing record 309 | Sex and the City 2
# Processsing record 310 | The Road to El Dorado
# Processsing record 311 | Ice Age: Continental Drift
# Processsing record 312 | Cinderella
# Processsing record 313 | The Lovely Bones
# Processsing record 314 | Finding Nemo
# Processsing record 315 | The Lord of the Rings: The Return of the King
# Processsing record 316 | The Lord of the Rings: The Two Towers
# Processsing record 317 | Seventh Son
# Processsing record 318 | Lara Croft: Tomb Raider
# Processsing record 319 | Transcendence
# Processsing record 320 | Jurassic Park III
# Processsing record 321 | Rise of the Planet of the Apes
# Processsing record 322 | The Spiderwick Chronicles
# Processsing record 323 | A Good Day to Die Hard
# Processsing record 324 | Cutthroat Island
# Processsing record 325 | Men in Black
# Processsing record 326 | Toy Story 2
# Processsing record 327 | Unstoppable
# Processsing record 328 | Rush Hour 2
# Processsing record 329 | What Lies Beneath
# Processsing record 330 | Cloudy with a Chance of Meatballs
# Processsing record 331 | Ice Age: Dawn of the Dinosaurs
# Processsing record 332 | The Secret Life of Walter Mitty
# Processsing record 333 | Charlie's Angels
# Processsing record 334 | The Departed
# Processsing record 335 | Mulan
# Processsing record 336 | Tropic Thunder
# Processsing record 337 | The Girl with the Dragon Tattoo
# Processsing record 338 | Die Hard: With a Vengeance
# Processsing record 339 | Sherlock Holmes
# Processsing record 340 | Ben-Hur
# Processsing record 341 | Atlantis: The Lost Empire
# Processsing record 342 | Valkyrie
# Processsing record 343 | You Don't Mess with the Zohan
# Processsing record 344 | Pixels
# Processsing record 345 | A.I. Artificial Intelligence
# Processsing record 346 | The Haunted Mansion
# Processsing record 347 | Contact
# Processsing record 348 | Hollow Man
# Processsing record 349 | The Interpreter
# Processsing record 350 | Percy Jackson: Sea of Monsters
# Processsing record 351 | Lara Croft Tomb Raider: The Cradle of Life
# Processsing record 352 | Now You See Me 2
# Processsing record 353 | The Saint
# Processsing record 354 | Spy Game
# Processsing record 355 | Rio
# Processsing record 356 | Bicentennial Man
# Processsing record 357 | The Devil's Own
# Processsing record 358 | K-19: The Widowmaker
# Processsing record 359 | Conan the Barbarian
# Processsing record 360 | Cinderella Man
# Processsing record 361 | Seabiscuit
# Processsing record 362 | Twister
# Processsing record 363 | Cast Away
# Processsing record 364 | Happy Feet
# Processsing record 365 | The Bourne Supremacy
# Processsing record 366 | Air Force One
# Processsing record 367 | Ocean's Eleven
# Processsing record 368 | The Three Musketeers
# Processsing record 369 | Hotel Transylvania
# Processsing record 370 | Enchanted
# Processsing record 371 | Safe House
# Processsing record 372 | 102 Dalmatians
# Processsing record 373 | Tower Heist
# Processsing record 374 | The Holiday
# Processsing record 375 | Enemy of the State
# Processsing record 376 | It's Complicated
# Processsing record 377 | Ocean's Thirteen
# Processsing record 378 | Open Season
# Processsing record 379 | Divergent
# Processsing record 380 | Enemy at the Gates
# Processsing record 381 | The Rundown
# Processsing record 382 | Last Action Hero
# Processsing record 383 | Memoirs of a Geisha
# Processsing record 384 | The Fast and the Furious: Tokyo Drift
# Processsing record 385 | Meet Joe Black
# Processsing record 386 | Collateral Damage
# Processsing record 387 | Mirror Mirror
# Processsing record 388 | Scott Pilgrim vs. the World
# Processsing record 389 | The Core
# Processsing record 390 | Nutty Professor II: The Klumps
# Processsing record 391 | Scooby-Doo
# Processsing record 392 | Dredd
# Processsing record 393 | Click
# Processsing record 394 | Creepshow
# Processsing record 395 | Cats & Dogs 2 : The Revenge of Kitty Galore
# Processsing record 396 | Jumper
# Processsing record 397 | Hellboy II: The Golden Army
# Processsing record 398 | Zodiac
# Processsing record 399 | The 6th Day
# Processsing record 400 | Bruce Almighty
# Processsing record 401 | The Expendables
# Processsing record 402 | Mission: Impossible
# Processsing record 403 | The Hunger Games
# Processsing record 404 | The Hangover Part II
# Processsing record 405 | Batman Returns
# Processsing record 406 | Over the Hedge
# Processsing record 407 | Lilo & Stitch
# Processsing record 408 | Charlotte's Web
# Processsing record 409 | Deep Impact
# Processsing record 410 | The Longest Yard
# Processsing record 411 | Alvin and the Chipmunks: Chipwrecked
# Processsing record 412 | Grown Ups 2
# Processsing record 413 | Get Smart
# Processsing record 414 | Something's Gotta Give
# Processsing record 415 | Shutter Island
# Processsing record 416 | Four Christmases
# Processsing record 417 | Robots
# Processsing record 418 | Face/Off
# Processsing record 419 | Bedtime Stories
# Processsing record 420 | Road to Perdition
# Processsing record 421 | Just Go with It
# Processsing record 422 | Con Air
# Processsing record 423 | Eagle Eye
# Processsing record 424 | Cold Mountain
# Processsing record 425 | The Book of Eli
# Processsing record 426 | Flubber
# Processsing record 427 | The Haunting
# Processsing record 428 | Space Jam
# Processsing record 429 | The Day the Earth Stood Still
# Processsing record 430 | Conspiracy Theory
# Processsing record 431 | Fury
# Processsing record 432 | Six Days Seven Nights
# Processsing record 433 | Yogi Bear
# Processsing record 434 | Spirit: Stallion of the Cimarron
# Processsing record 435 | Zookeeper
# Processsing record 436 | Lost in Space
# Processsing record 437 | The Manchurian Candidate
# Processsing record 438 | Hotel Transylvania 2
# Processsing record 439 | Fantasia 2000
# Processsing record 440 | The Time Machine
# Processsing record 441 | Swordfish
# Processsing record 442 | The Legend of Zorro
# Processsing record 443 | What Dreams May Come
# Processsing record 444 | The Brothers Grimm
# Processsing record 445 | Mars Attacks!
# Processsing record 446 | Surrogates
# Processsing record 447 | Thirteen Days
# Processsing record 448 | Daylight
# Processsing record 449 | Battlefield Earth
# Processsing record 450 | Looney Tunes: Back in Action
# Processsing record 451 | Nine
# Processsing record 452 | Timeline
# Processsing record 453 | The Postman
# Processsing record 454 | Babe: Pig in the City
# Processsing record 455 | The Last Witch Hunter
# Processsing record 456 | Red Planet
# Processsing record 457 | Arthur and the Invisibles
# Processsing record 458 | A Sound of Thunder
# Processsing record 459 | Pompeii
# Processsing record 460 | A Beautiful Mind
# Processsing record 461 | Journey 2: The Mysterious Island
# Processsing record 462 | Cloudy with a Chance of Meatballs 2
# Processsing record 463 | Red Dragon
# Processsing record 464 | Hidalgo
# Processsing record 465 | Jack and Jill
# Processsing record 466 | 2 Fast 2 Furious
# Processsing record 467 | The Little Prince
# Processsing record 468 | The Invasion
# Processsing record 469 | The Adventures of Rocky & Bullwinkle
# Processsing record 470 | The Secret Life of Pets
# Processsing record 471 | The League of Extraordinary Gentlemen
# Processsing record 472 | Despicable Me 2
# Processsing record 473 | Independence Day
# Processsing record 474 | The Lost World: Jurassic Park
# Processsing record 475 | Madagascar
# Processsing record 476 | Children of Men
# Processsing record 477 | X-Men
# Processsing record 478 | Wanted
# Processsing record 479 | The Rock
# Processsing record 480 | Ice Age: The Meltdown
# Processsing record 481 | 50 First Dates
# Processsing record 482 | Hairspray
# Processsing record 483 | Exorcist: The Beginning
# Processsing record 484 | Now You See Me
# Processsing record 485 | Grown Ups
# Processsing record 486 | The Terminal
# Processsing record 487 | Hotel for Dogs
# Processsing record 488 | Vertical Limit
# Processsing record 489 | Charlie Wilson's War
# Processsing record 490 | Shark Tale
# Processsing record 491 | Dreamgirls
# Processsing record 492 | Be Cool
# Processsing record 493 | Munich
# Processsing record 494 | Tears of the Sun
# Processsing record 495 | Killers
# Processsing record 496 | The Man from U.N.C.L.E.
# Processsing record 497 | Spanglish
# Processsing record 498 | Monster House
# Processsing record 499 | Bandits
# Processsing record 500 | First Knight
# Processsing record 501 | Immortals
# Processsing record 502 | Hostage
# Processsing record 503 | Titan A.E.
# Processsing record 504 | Hollywood Homicide
# Processsing record 505 | Soldier
# Processsing record 506 | Monkeybone
# Processsing record 507 | Flight of the Phoenix
# Processsing record 508 | Unbreakable
# Processsing record 509 | Sucker Punch
# Processsing record 510 | Snake Eyes
# Processsing record 511 | Sphere
# Processsing record 512 | The Angry Birds Movie
# Processsing record 513 | Fool's Gold
# Processsing record 514 | Funny People
# Processsing record 515 | The Kingdom
# Processsing record 516 | Talladega Nights: The Ballad of Ricky Bobby
# Processsing record 517 | Dr. Dolittle 2
# Processsing record 518 | Braveheart
# Processsing record 519 | Jarhead
# Processsing record 520 | The Simpsons Movie
# Processsing record 521 | The Majestic
# Processsing record 522 | Driven
# Processsing record 523 | Two Brothers
# Processsing record 524 | The Village
# Processsing record 525 | Doctor Dolittle
# Processsing record 526 | Signs
# Processsing record 527 | Shrek 2
# Processsing record 528 | Cars
# Processsing record 529 | Runaway Bride
# Processsing record 530 | xXx
# Processsing record 531 | The SpongeBob Movie: Sponge Out of Water
# Processsing record 532 | Ransom
# Processsing record 533 | Inglourious Basterds
# Processsing record 534 | Hook
# Processsing record 535 | Die Hard 2
# Processsing record 536 | S.W.A.T.
# Processsing record 537 | Vanilla Sky
# Processsing record 538 | Lady in the Water
# Processsing record 539 | Alvin and the Chipmunks: The Squeakquel
# Processsing record 540 | We Were Soldiers
# Processsing record 541 | Olympus Has Fallen
# Processsing record 542 | Star Trek: Insurrection
# Processsing record 543 | Battle: Los Angeles
# Processsing record 544 | Big Fish
# Processsing record 545 | War Horse
# Processsing record 546 | The Monuments Men
# Processsing record 547 | The Abyss
# Processsing record 548 | Wall Street: Money Never Sleeps
# Processsing record 549 | Dracula Untold
# Processsing record 550 | The Siege
# Processsing record 551 | Stardust
# Processsing record 552 | Seven Years in Tibet
# Processsing record 553 | The Dilemma
# Processsing record 554 | Bad Company
# Processsing record 555 | Doom
# Processsing record 556 | I Spy
# Processsing record 557 | Underworld: Awakening
# Processsing record 558 | Rock of Ages
# Processsing record 559 | Hart's War
# Processsing record 560 | Killer Elite
# Processsing record 561 | Ballistic: Ecks vs. Sever
# Processsing record 562 | Hard Rain
# Processsing record 563 | Osmosis Jones
# Processsing record 564 | Legends of Oz: Dorothy's Return
# Processsing record 565 | Blackhat
# Processsing record 566 | Sky Captain and the World of Tomorrow
# Processsing record 567 | Basic Instinct 2
# Processsing record 568 | Escape Plan
# Processsing record 569 | The Legend of Hercules
# Processsing record 570 | The Sum of All Fears
# Processsing record 571 | The Twilight Saga: Eclipse
# Processsing record 572 | The Score
# Processsing record 573 | Despicable Me
# Processsing record 574 | Money Train
# Processsing record 575 | Ted 2
# Processsing record 576 | Agora
# Processsing record 577 | Mystery Men
# Processsing record 578 | Hall Pass
# Processsing record 579 | The Insider
# Processsing record 580 | The Finest Hours
# Processsing record 581 | Body of Lies
# Processsing record 582 | Dinner for Schmucks
# Processsing record 583 | Abraham Lincoln: Vampire Hunter
# Processsing record 584 | Entrapment
# Processsing record 585 | The X Files
# Processsing record 586 | The Last Legion
# Processsing record 587 | Saving Private Ryan
# Processsing record 588 | Need for Speed
# Processsing record 589 | What Women Want
# Processsing record 590 | Ice Age
# Processsing record 591 | Dreamcatcher
# Processsing record 592 | Lincoln
# Processsing record 593 | The Matrix
# Processsing record 594 | Apollo 13
# Processsing record 595 | The Santa Clause 2
# Processsing record 596 | You've Got Mail
# Processsing record 597 | Step Brothers
# Processsing record 598 | The Mask of Zorro
# Processsing record 599 | Due Date
# Processsing record 600 | Unbroken
# Processsing record 601 | Space Cowboys
# Processsing record 602 | Cliffhanger
# Processsing record 603 | Broken Arrow
# Processsing record 604 | The Kid
# Processsing record 605 | World Trade Center
# Processsing record 606 | The Dictator
# Processsing record 607 | Eyes Wide Shut
# Processsing record 608 | Annie
# Processsing record 609 | Focus
# Processsing record 610 | This Means War
# Processsing record 611 | Blade: Trinity
# Processsing record 612 | Red Dawn
# Processsing record 613 | Resident Evil: Retribution
# Processsing record 614 | Death Race
# Processsing record 615 | The Long Kiss Goodnight
# Processsing record 616 | Zathura: A Space Adventure
# Processsing record 617 | Fight Club
# Processsing record 618 | We Are Marshall
# Processsing record 619 | Hudson Hawk
# Processsing record 620 | I, Frankenstein
# Processsing record 621 | Elektra
# Processsing record 622 | Sin City: A Dame to Kill For
# Processsing record 623 | Random Hearts
# Processsing record 624 | Everest
# Processsing record 625 | Perfume: The Story of a Murderer
# Processsing record 626 | Austin Powers in Goldmember
# Processsing record 627 | Astro Boy
# Processsing record 628 | Jurassic Park
# Processsing record 629 | Wyatt Earp
# Processsing record 630 | Clear and Present Danger
# Processsing record 631 | Dragon Blade
# Processsing record 632 | Little Man
# Processsing record 633 | U-571
# Processsing record 634 | The American President
# Processsing record 635 | The Love Guru
# Processsing record 636 | 3000 Miles to Graceland
# Processsing record 637 | The Hateful Eight
# Processsing record 638 | Hop
# Processsing record 639 | 300
# Processsing record 640 | Meet the Fockers
# Processsing record 641 | Marley & Me
# Processsing record 642 | The Green Mile
# Processsing record 643 | Chicken Little
# Processsing record 644 | Gone Girl
# Processsing record 645 | The Bourne Identity
# Processsing record 646 | GoldenEye
# Processsing record 647 | The General's Daughter
# Processsing record 648 | The Truman Show
# Processsing record 649 | The Prince of Egypt
# Processsing record 650 | Daddy Day Care
# Processsing record 651 | 2 Guns
# Processsing record 652 | Cats & Dogs
# Processsing record 653 | The Italian Job
# Processsing record 654 | Two Weeks Notice
# Processsing record 655 | Antz
# Processsing record 656 | Couples Retreat
# Processsing record 657 | Days of Thunder
# Processsing record 658 | Cheaper by the Dozen 2
# Processsing record 659 | Maze Runner: The Scorch Trials
# Processsing record 660 | Eat Pray Love
# Processsing record 661 | RED
# Processsing record 662 | Any Given Sunday
# Processsing record 663 | The Horse Whisperer
# Processsing record 664 | Collateral
# Processsing record 665 | The Scorpion King
# Processsing record 666 | Ladder 49
# Processsing record 667 | Jack Reacher
# Processsing record 668 | Deep Blue Sea
# Processsing record 669 | Contagion
# Processsing record 670 | Coraline
# Processsing record 671 | The Happening
# Processsing record 672 | Man on Fire
# Processsing record 673 | The Shaggy Dog
# Processsing record 674 | Starsky & Hutch
# Processsing record 675 | Jingle All the Way
# Processsing record 676 | Hellboy
# Processsing record 677 | A Civil Action
# Processsing record 678 | ParaNorman
# Processsing record 679 | The Jackal
# Processsing record 680 | Paycheck
# Processsing record 681 | The Tale of Despereaux
# Processsing record 682 | Under Siege 2: Dark Territory
# Processsing record 683 | Jack Ryan: Shadow Recruit
# Processsing record 684 | Joy
# Processsing record 685 | London Has Fallen
# Processsing record 686 | Alien: Resurrection
# Processsing record 687 | Shooter
# Processsing record 688 | The Boxtrolls
# Processsing record 689 | Practical Magic
# Processsing record 690 | The Lego Movie
# Processsing record 691 | Reign of Fire
# Processsing record 692 | Gangster Squad
# Processsing record 693 | Year One
# Processsing record 694 | Invictus
# Processsing record 695 | State of Play
# Processsing record 696 | Duplicity
# Processsing record 697 | My Favorite Martian
# Processsing record 698 | The Sentinel
# Processsing record 699 | Planet 51
# Processsing record 700 | Star Trek: Nemesis
# Processsing record 701 | Intolerable Cruelty
# Processsing record 702 | Edge of Darkness
# Processsing record 703 | The Relic
# Processsing record 704 | Analyze That
# Processsing record 705 | Righteous Kill
# Processsing record 706 | The Soloist
# Processsing record 707 | The Legend of Bagger Vance
# Processsing record 708 | Almost Famous
# Processsing record 709 | xXx: State of the Union
# Processsing record 710 | Priest
# Processsing record 711 | Sinbad: Legend of the Seven Seas
# Processsing record 712 | Event Horizon
# Processsing record 713 | Dragonfly
# Processsing record 714 | The Black Dahlia
# Processsing record 715 | Flyboys
# Processsing record 716 | The Last Castle
# Processsing record 717 | Supernova
# Processsing record 718 | Winter's Tale
# Processsing record 719 | The Mortal Instruments: City of Bones
# Processsing record 720 | Meet Dave
# Processsing record 721 | Dark Water
# Processsing record 722 | Inkheart
# Processsing record 723 | The Spirit
# Processsing record 724 | Mortdecai
# Processsing record 725 | The Great Raid
# Processsing record 726 | Deadpool
# Processsing record 727 | American Sniper
# Processsing record 728 | Goosebumps
# Processsing record 729 | Just Like Heaven
# Processsing record 730 | The Flintstones in Viva Rock Vegas
# Processsing record 731 | Rambo III
# Processsing record 732 | Leatherheads
# Processsing record 733 | Did You Hear About the Morgans?
# Processsing record 734 | The Internship
# Processsing record 735 | Resident Evil: Afterlife
# Processsing record 736 | Red Tails
# Processsing record 737 | The Devil's Advocate
# Processsing record 738 | DragonHeart
# Processsing record 739 | After the Sunset
# Processsing record 740 | Ghost Rider: Spirit of Vengeance
# Processsing record 741 | Captain Corelli's Mandolin
# Processsing record 742 | The Pacifier
# Processsing record 743 | Walking Tall
# Processsing record 744 | Forrest Gump
# Processsing record 745 | Alvin and the Chipmunks
# Processsing record 746 | Meet the Parents
# Processsing record 747 | Pocahontas
# Processsing record 748 | Superman
# Processsing record 749 | The Nutty Professor
# Processsing record 750 | Hitch
# Processsing record 751 | American Wedding
# Processsing record 752 | Captain Phillips
# Processsing record 753 | Date Night
# Processsing record 754 | Casper
# Processsing record 755 | The Equalizer
# Processsing record 756 | Maid in Manhattan
# Processsing record 757 | Crimson Tide
# Processsing record 758 | The Pursuit of Happyness
# Processsing record 759 | Flightplan
# Processsing record 760 | Disclosure
# Processsing record 761 | Kill Bill: Vol. 1
# Processsing record 762 | Kill Bill: Vol. 2
# Processsing record 763 | Tango & Cash
# Processsing record 764 | Shanghai Noon
# Processsing record 765 | Executive Decision
# Processsing record 766 | Mr. Popper's Penguins
# Processsing record 767 | The Forbidden Kingdom
# Processsing record 768 | Free Birds
# Processsing record 769 | Evita
# Processsing record 770 | Ronin
# Processsing record 771 | The Ghost and the Darkness
# Processsing record 772 | Paddington
# Processsing record 773 | The Watch
# Processsing record 774 | The Hunted
# Processsing record 775 | Changeling
# Processsing record 776 | Chain Reaction
# Processsing record 777 | The Fan
# Processsing record 778 | The Phantom of the Opera
# Processsing record 779 | Elizabeth: The Golden Age
# Processsing record 780 | Gods and Generals
# Processsing record 781 | Turbulence
# Processsing record 782 | Muppets Most Wanted
# Processsing record 783 | Thunderbirds
# Processsing record 784 | Burlesque
# Processsing record 785 | Lolita
# Processsing record 786 | Blade II
# Processsing record 787 | Seven Pounds
# Processsing record 788 | Bullet to the Head
# Processsing record 789 | The Godfather: Part III
# Processsing record 790 | Elizabethtown
# Processsing record 791 | You, Me and Dupree
# Processsing record 792 | Superman II
# Processsing record 793 | Shaft
# Processsing record 794 | Anastasia
# Processsing record 795 | Moulin Rouge!
# Processsing record 796 | Domestic Disturbance
# Processsing record 797 | Black Mass
# Processsing record 798 | Flags of Our Fathers
# Processsing record 799 | Law Abiding Citizen
# Processsing record 800 | Grindhouse
# Processsing record 801 | Catch Me If You Can
# Processsing record 802 | Zero Dark Thirty
# Processsing record 803 | The Break-Up
# Processsing record 804 | Mamma Mia!
# Processsing record 805 | Valentine's Day
# Processsing record 806 | The Dukes of Hazzard
# Processsing record 807 | The Thin Red Line
# Processsing record 808 | The Change-Up
# Processsing record 809 | Man on the Moon
# Processsing record 810 | Casino
# Processsing record 811 | From Paris with Love
# Processsing record 812 | Me, Myself & Irene
# Processsing record 813 | Barnyard
# Processsing record 814 | The Twilight Saga: New Moon
# Processsing record 815 | Shrek
# Processsing record 816 | The Adjustment Bureau
# Processsing record 817 | Robin Hood: Prince of Thieves
# Processsing record 818 | Jerry Maguire
# Processsing record 819 | Ted
# Processsing record 820 | As Good as It Gets
# Processsing record 821 | Patch Adams
# Processsing record 822 | Anchorman 2: The Legend Continues
# Processsing record 823 | Mr. Deeds
# Processsing record 824 | Super 8
# Processsing record 825 | Erin Brockovich
# Processsing record 826 | How to Lose a Guy in 10 Days
# Processsing record 827 | 22 Jump Street
# Processsing record 828 | Interview with the Vampire
# Processsing record 829 | Yes Man
# Processsing record 830 | Central Intelligence
# Processsing record 831 | Daddy's Home
# Processsing record 832 | Into the Woods
# Processsing record 833 | Inside Man
# Processsing record 834 | Payback
# Processsing record 835 | Congo
# Processsing record 836 | We Bought a Zoo
# Processsing record 837 | Knowing
# Processsing record 838 | Failure to Launch
# Processsing record 839 | The Ring Two
# Processsing record 840 | Crazy, Stupid, Love.
# Processsing record 841 | Garfield
# Processsing record 842 | Moneyball
# Processsing record 843 | Outbreak
# Processsing record 844 | Non-Stop
# Processsing record 845 | Race to Witch Mountain
# Processsing record 846 | V for Vendetta
# Processsing record 847 | Shanghai Knights
# Processsing record 848 | Curious George
# Processsing record 849 | Herbie Fully Loaded
# Processsing record 850 | Don't Say a Word
# Processsing record 851 | Hansel & Gretel: Witch Hunters
# Processsing record 852 | Unfaithful
# Processsing record 853 | I Am Number Four
# Processsing record 854 | Syriana
# Processsing record 855 | The Book of Life
# Processsing record 856 | Firewall
# Processsing record 857 | Absolute Power
# Processsing record 858 | G.I. Jane
# Processsing record 859 | The Game
# Processsing record 860 | Silent Hill
# Processsing record 861 | American Reunion
# Processsing record 862 | Into the Storm
# Processsing record 863 | Beverly Hills Cop III
# Processsing record 864 | Gremlins 2: The New Batch
# Processsing record 865 | The Judge
# Processsing record 866 | Resident Evil: Apocalypse
# Processsing record 867 | Bridget Jones: The Edge of Reason
# Processsing record 868 | On Deadly Ground
# Processsing record 869 | The Adventures of Sharkboy and Lavagirl
# Processsing record 870 | The Beach
# Processsing record 871 | Raising Helen
# Processsing record 872 | Ninja Assassin
# Processsing record 873 | Striptease
# Processsing record 874 | Marmaduke
# Processsing record 875 | Hereafter
# Processsing record 876 | Assassins
# Processsing record 877 | Hannibal Rising
# Processsing record 878 | The Story of Us
# Processsing record 879 | The Host
# Processsing record 880 | Basic
# Processsing record 881 | Blood Work
# Processsing record 882 | The International
# Processsing record 883 | Escape from L.A.
# Processsing record 884 | The Iron Giant
# Processsing record 885 | The Life Aquatic with Steve Zissou
# Processsing record 886 | Free State of Jones
# Processsing record 887 | The Life of David Gale
# Processsing record 888 | Run All Night
# Processsing record 889 | Eastern Promises
# Processsing record 890 | Into the Blue
# Processsing record 891 | The Messenger: The Story of Joan of Arc
# Processsing record 892 | Your Highness
# Processsing record 893 | Dream House
# Processsing record 894 | Mad City
# Processsing record 895 | Baby's Day Out
# Processsing record 896 | The Scarlet Letter
# Processsing record 897 | Fair Game
# Processsing record 898 | Jade
# Processsing record 899 | Gamer
# Processsing record 900 | Beautiful Creatures
# Processsing record 901 | Zoolander 2
# Processsing record 902 | The Big Bounce
# Processsing record 903 | Drive Angry
# Processsing record 904 | Street Fighter: The Legend of Chun-Li
# Processsing record 905 | The One
# Processsing record 906 | The Adventures of Ford Fairlane
# Processsing record 907 | Traffic
# Processsing record 908 | Indiana Jones and the Last Crusade
# Processsing record 909 | Chappie
# Processsing record 910 | The Bone Collector
# Processsing record 911 | Panic Room
# Processsing record 912 | Three Kings
# Processsing record 913 | Child 44
# Processsing record 914 | Rat Race
# Processsing record 915 | K-PAX
# Processsing record 916 | Bedazzled
# Processsing record 917 | The Cotton Club
# Processsing record 918 | 3:10 to Yuma
# Processsing record 919 | Taken 3
# Processsing record 920 | Out of Sight
# Processsing record 921 | The Cable Guy
# Processsing record 922 | Dick Tracy
# Processsing record 923 | The Thomas Crown Affair
# Processsing record 924 | Riding in Cars with Boys
# Processsing record 925 | First Blood
# Processsing record 926 | Happily N'Ever After
# Processsing record 927 | Mary Reilly
# Processsing record 928 | My Best Friend's Wedding
# Processsing record 929 | Insomnia
# Processsing record 930 | Star Trek: First Contact
# Processsing record 931 | Jonah Hex
# Processsing record 932 | Courage Under Fire
# Processsing record 933 | Liar Liar
# Processsing record 934 | The Infiltrator
# Processsing record 935 | Inchon
# Processsing record 936 | The Flintstones
# Processsing record 937 | Taken 2
# Processsing record 938 | Scary Movie 3
# Processsing record 939 | Miss Congeniality
# Processsing record 940 | Journey to the Center of the Earth
# Processsing record 941 | The Princess Diaries 2: Royal Engagement
# Processsing record 942 | The Pelican Brief
# Processsing record 943 | The Client
# Processsing record 944 | The Bucket List
# Processsing record 945 | Patriot Games
# Processsing record 946 | Monster-in-Law
# Processsing record 947 | Prisoners
# Processsing record 948 | Training Day
# Processsing record 949 | Galaxy Quest
# Processsing record 950 | Scary Movie 2
# Processsing record 951 | The Muppets
# Processsing record 952 | Blade
# Processsing record 953 | Coach Carter
# Processsing record 954 | Changing Lanes
# Processsing record 955 | Anaconda
# Processsing record 956 | Coyote Ugly
# Processsing record 957 | Love Actually
# Processsing record 958 | A Bug's Life
# Processsing record 959 | From Hell
# Processsing record 960 | The Specialist
# Processsing record 961 | Tin Cup
# Processsing record 962 | Kicking & Screaming
# Processsing record 963 | The Hitchhiker's Guide to the Galaxy
# Processsing record 964 | Resident Evil: Extinction
# Processsing record 965 | Blended
# Processsing record 966 | Last Holiday
# Processsing record 967 | Savages
# Processsing record 968 | Cellular
# Processsing record 969 | Johnny English
# Processsing record 970 | The Ant Bully
# Processsing record 971 | Dune
# Processsing record 972 | Revolutionary Road
# Processsing record 973 | 16 Blocks
# Processsing record 974 | Babylon A.D.
# Processsing record 975 | Aliens in the Attic
# Processsing record 976 | The Pledge
# Processsing record 977 | The Producers
# Processsing record 978 | The Phantom
# Processsing record 979 | Nixon
# Processsing record 980 | The Ghost Writer
# Processsing record 981 | Deep Rising
# Processsing record 982 | Miracle at St. Anna
# Processsing record 983 | Bangkok Dangerous
# Processsing record 984 | Big Trouble
# Processsing record 985 | Love in the Time of Cholera
# Processsing record 986 | Shadow Conspiracy
# Processsing record 987 | Johnny English Reborn
# Processsing record 988 | Argo
# Processsing record 989 | The Fugitive
# Processsing record 990 | The Bounty Hunter
# Processsing record 991 | Sleepers
# Processsing record 992 | Rambo: First Blood Part II
# Processsing record 993 | Heaven's Gate
# Processsing record 994 | Underworld: Evolution
# Processsing record 995 | Finding Forrester
# Processsing record 996 | Unleashed
# Processsing record 997 | The Sweetest Thing
# Processsing record 998 | The Firm
# Processsing record 999 | Charlie St. Cloud
# Processsing record 1000 | The Mechanic
# Processsing record 1001 | 21 Jump Street
# Processsing record 1002 | Notting Hill
# Processsing record 1003 | Chicken Run
# Processsing record 1004 | Along Came Polly
# Processsing record 1005 | Boomerang
# Processsing record 1006 | The Heat
# Processsing record 1007 | Cleopatra
# Processsing record 1008 | The Mothman Prophecies
# Processsing record 1009 | Licence to Kill
# Processsing record 1010 | Red Riding Hood
# Processsing record 1011 | 15 Minutes
# Processsing record 1012 | Super Mario Bros.
# Processsing record 1013 | Lord of War
# Processsing record 1014 | One for the Money
# Processsing record 1015 | The Interview
# Processsing record 1016 | The Warrior's Way
# Processsing record 1017 | Micmacs
# Processsing record 1018 | 8 Mile
# Processsing record 1019 | A Knight's Tale
# Processsing record 1020 | Man on a Ledge
# Processsing record 1021 | The Big Year
# Processsing record 1022 | The Karate Kid
# Processsing record 1023 | American Hustle
# Processsing record 1024 | The Proposal
# Processsing record 1025 | Double Jeopardy
# Processsing record 1026 | Back to the Future Part II
# Processsing record 1027 | Lucy
# Processsing record 1028 | Fifty Shades of Grey
# Processsing record 1029 | Spy Kids 3-D: Game Over
# Processsing record 1030 | A Time to Kill
# Processsing record 1031 | Cheaper by the Dozen
# Processsing record 1032 | Lone Survivor
# Processsing record 1033 | A League of Their Own
# Processsing record 1034 | The Conjuring 2
# Processsing record 1035 | The Social Network
# Processsing record 1036 | He's Just Not That Into You
# Processsing record 1037 | Scary Movie 4
# Processsing record 1038 | Scream 3
# Processsing record 1039 | Back to the Future Part III
# Processsing record 1040 | Get Hard
# Processsing record 1041 | Dracula
# Processsing record 1042 | 42
# Processsing record 1043 | The Talented Mr. Ripley
# Processsing record 1044 | Dumb and Dumber To
# Processsing record 1045 | Eight Below
# Processsing record 1046 | The Intern
# Processsing record 1047 | Ride Along 2
# Processsing record 1048 | The Last of the Mohicans
# Processsing record 1049 | Ray
# Processsing record 1050 | Sin City
# Processsing record 1051 | Vantage Point
# Processsing record 1052 | I Love You, Man
# Processsing record 1053 | Shallow Hal
# Processsing record 1054 | JFK
# Processsing record 1055 | Big Momma's House 2
# Processsing record 1056 | The Mexican
# Processsing record 1057 | 17 Again
# Processsing record 1058 | The Other Woman
# Processsing record 1059 | The Final Destination
# Processsing record 1060 | Bridge of Spies
# Processsing record 1061 | Behind Enemy Lines
# Processsing record 1062 | Get Him to the Greek
# Processsing record 1063 | Shall We Dance?
# Processsing record 1064 | Small Soldiers
# Processsing record 1065 | Spawn
# Processsing record 1066 | The Count of Monte Cristo
# Processsing record 1067 | The Lincoln Lawyer
# Processsing record 1068 | Unknown
# Processsing record 1069 | The Prestige
# Processsing record 1070 | Horrible Bosses 2
# Processsing record 1071 | Escape from Planet Earth
# Processsing record 1072 | Apocalypto
# Processsing record 1073 | The Living Daylights
# Processsing record 1074 | Predators
# Processsing record 1075 | Secret Window
# Processsing record 1076 | The Lake House
# Processsing record 1077 | The Skeleton Key
# Processsing record 1078 | Made of Honor
# Processsing record 1079 | Jersey Boys
# Processsing record 1080 | The Rainmaker
# Processsing record 1081 | Gothika
# Processsing record 1082 | Amistad
# Processsing record 1083 | Aliens vs Predator: Requiem
# Processsing record 1084 | Music and Lyrics
# Processsing record 1085 | Paul
# Processsing record 1086 | The Guilt Trip
# Processsing record 1087 | Scream 4
# Processsing record 1088 | 8MM
# Processsing record 1089 | The Doors
# Processsing record 1090 | Sex Tape
# Processsing record 1091 | Hanging Up
# Processsing record 1092 | Final Destination 5
# Processsing record 1093 | Pay It Forward
# Processsing record 1094 | Fever Pitch
# Processsing record 1095 | The Shadow
# Processsing record 1096 | Extremely Loud & Incredibly Close
# Processsing record 1097 | Morning Glory
# Processsing record 1098 | Get Rich or Die Tryin'
# Processsing record 1099 | The Art of War
# Processsing record 1100 | Rent
# Processsing record 1101 | The Out-of-Towners
# Processsing record 1102 | The Island of Dr. Moreau
# Processsing record 1103 | The Musketeer
# Processsing record 1104 | Sweet November
# Processsing record 1105 | The Reaping
# Processsing record 1106 | Mean Streets
# Processsing record 1107 | Renaissance Man
# Processsing record 1108 | Colombiana
# Processsing record 1109 | Quest for Camelot
# Processsing record 1110 | City By The Sea
# Processsing record 1111 | Torque
# Processsing record 1112 | Showgirls
# Processsing record 1113 | Marie Antoinette
# Processsing record 1114 | Get Carter
# Processsing record 1115 | The Impossible
# Processsing record 1116 | Ishtar
# Processsing record 1117 | Fantastic Mr. Fox
# Processsing record 1118 | Life or Something Like It
# Processsing record 1119 | Memoirs of an Invisible Man
# Processsing record 1120 | Alfie
# Processsing record 1121 | Big Miracle
# Processsing record 1122 | The Deep End of the Ocean
# Processsing record 1123 | FearDotCom
# Processsing record 1124 | Cirque du Freak: The Vampire's Assistant
# Processsing record 1125 | Duplex
# Processsing record 1126 | Universal Soldier: The Return
# Processsing record 1127 | Pandorum
# Processsing record 1128 | Extreme Ops
# Processsing record 1129 | A Thousand Words
# Processsing record 1130 | The Gunman
# Processsing record 1131 | Stormbreaker
# Processsing record 1132 | Disturbia
# Processsing record 1133 | Hackers
# Processsing record 1134 | Snowpiercer
# Processsing record 1135 | The Crow
# Processsing record 1136 | The Time Traveler's Wife
# Processsing record 1137 | Frankenweenie
# Processsing record 1138 | Serenity
# Processsing record 1139 | Against the Ropes
# Processsing record 1140 | Superman III
# Processsing record 1141 | Grudge Match
# Processsing record 1142 | Red Cliff
# Processsing record 1143 | Sweet Home Alabama
# Processsing record 1144 | The Ugly Truth
# Processsing record 1145 | Star Trek: Generations
# Processsing record 1146 | Water for Elephants
# Processsing record 1147 | The Hurricane
# Processsing record 1148 | Enough
# Processsing record 1149 | Paul Blart: Mall Cop 2
# Processsing record 1150 | The Ninth Gate
# Processsing record 1151 | Extreme Measures
# Processsing record 1152 | Precious
# Processsing record 1153 | White Squall
# Processsing record 1154 | The Thing
# ...
# Processsing record 2520 | The Wackness
# Processsing record 2521 | Beastmaster 2: Through the Portal of Time
# Processsing record 2522 | The 5th Quarter
# Processsing record 2523 | Snow Flower and the Secret Fan
# Processsing record 2524 | Surfer, Dude
# Processsing record 2525 | Deadfall
# Processsing record 2526 | Videodrome
# Processsing record 2527 | Song One
# Processsing record 2528 | The Train
# Processsing record 2529 | The Protector
# Processsing record 2530 | Crossover
# Processsing record 2531 | Chariots of Fire
# Processsing record 2532 | High Plains Drifter
# Processsing record 2533 | Galaxina
# Processsing record 2534 | Mambo Italiano
# Processsing record 2535 | Wonderland
# Processsing record 2536 | Do the Right Thing
# Processsing record 2537 | Miss Julie
# Processsing record 2538 | 10 Cloverfield Lane
# Processsing record 2539 | Jackass: The Movie
# Processsing record 2540 | Lights Out
# Processsing record 2541 | A Nightmare on Elm Street 3: Dream Warriors
# Processsing record 2542 | The Robe
# Processsing record 2543 | The Return of the Pink Panther
# Processsing record 2544 | Monster
# Processsing record 2545 | 20,000 Leagues Under the Sea
# Processsing record 2546 | The Elephant Man
# Processsing record 2547 | Dallas Buyers Club
# Processsing record 2548 | Memento
# Processsing record 2549 | Oculus
# Processsing record 2550 | Clerks II
# Processsing record 2551 | The Way Way Back
# Processsing record 2552 | The Man from Snowy River
# Processsing record 2553 | Our Idiot Brother
# Processsing record 2554 | Race
# Processsing record 2555 | As Above, So Below
# Processsing record 2556 | Still Alice
# Processsing record 2557 | Nighthawks
# Processsing record 2558 | Spring Breakers
# Processsing record 2559 | Halloween: The Curse of Michael Myers
# Processsing record 2560 | Shaun of the Dead
# Processsing record 2561 | Lone Star
# Processsing record 2562 | Halloween 4: The Return of Michael Myers
# Processsing record 2563 | Lone Wolf McQuade
# Processsing record 2564 | Apollo 18
# Processsing record 2565 | Sunshine Cleaning
# Processsing record 2566 | No Escape
# Processsing record 2567 | Solomon and Sheba
# Processsing record 2568 | Fifty Shades of Black
# Processsing record 2569 | A Farewell to Arms
# Processsing record 2570 | The Barbarian Invasions
# Processsing record 2571 | Force 10 from Navarone
# Processsing record 2572 | Once Upon a Time in the West
# Processsing record 2573 | Made
# Processsing record 2574 | Moon
# Processsing record 2575 | Of Gods and Men
# Processsing record 2576 | Bottle Shock
# Processsing record 2577 | Heavenly Creatures
# Processsing record 2578 | 90 Minutes in Heaven
# Processsing record 2579 | Everything Must Go
# Processsing record 2580 | Zero Effect
# Processsing record 2581 | The Machinist
# Processsing record 2582 | Kill the Messenger
# Processsing record 2583 | Rabbit Hole
# Processsing record 2584 | Party Monster
# Processsing record 2585 | Green Room
# Processsing record 2586 | Bottle Rocket
# Processsing record 2587 | Tucker and Dale vs Evil
# Processsing record 2588 | Redacted
# Processsing record 2589 | Soul Kitchen
# Processsing record 2590 | The Awakening
# Processsing record 2591 | Take Shelter
# Processsing record 2592 | The Texas Chainsaw Massacre 2
# Processsing record 2593 | Pat Garrett & Billy the Kid
# Processsing record 2594 | Only God Forgives
# Processsing record 2595 | The Blue Lagoon
# Processsing record 2596 | Fast Times at Ridgemont High
# Processsing record 2597 | Moby Dick
# Processsing record 2598 | 25th Hour
# Processsing record 2599 | Bound
# Processsing record 2600 | Requiem for a Dream
# Processsing record 2601 | Moms' Night Out
# Processsing record 2602 | Donnie Darko
# Processsing record 2603 | Life During Wartime
# Processsing record 2604 | Airlift
# Processsing record 2605 | The Sweeney
# Processsing record 2606 | Whale Rider
# Processsing record 2607 | Night Watch
# Processsing record 2608 | Annie Hall
# Processsing record 2609 | The Greatest Show on Earth
# Processsing record 2610 | Monster's Ball
# Processsing record 2611 | Maggie
# Processsing record 2612 | Leaving Las Vegas
# Processsing record 2613 | The Boy Next Door
# Processsing record 2614 | Trapeze
# Processsing record 2615 | The Kids Are All Right
# Processsing record 2616 | They Live
# Processsing record 2617 | The Great Escape
# Processsing record 2618 | The Last Exorcism Part II
# Processsing record 2619 | Boyhood
# Processsing record 2620 | Scoop
# Processsing record 2621 | The Wash
# Processsing record 2622 | 3 Strikes
# Processsing record 2623 | The Misfits
# Processsing record 2624 | Topaz
# Processsing record 2625 | Let's Go to Prison
# Processsing record 2626 | Four Rooms
# Processsing record 2627 | Secretary
# Processsing record 2628 | Talk Radio
# Processsing record 2629 | You Kill Me
# Processsing record 2630 | Red State
# Processsing record 2631 | Mirrormask
# Processsing record 2632 | Joe
# Processsing record 2633 | Shooting Fish
# Processsing record 2634 | Prison
# Processsing record 2635 | Trust
# Processsing record 2636 | Adore
# Processsing record 2637 | Mondays in the Sun
# Processsing record 2638 | Stake Land
# Processsing record 2639 | Another Happy Day
# Processsing record 2640 | A Lonely Place to Die
# Processsing record 2641 | Hell's Angels
# Processsing record 2642 | A Man for All Seasons
# Processsing record 2643 | Network
# Processsing record 2644 | Major Dundee
# Processsing record 2645 | Annie Get Your Gun
# Processsing record 2646 | Four Lions
# Processsing record 2647 | Defendor
# Processsing record 2648 | The Pirate
# Processsing record 2649 | The History Boys
# Processsing record 2650 | Midnight Cowboy
# Processsing record 2651 | Menace II Society
# Processsing record 2652 | Creepshow 2
# Processsing record 2653 | The Ballad of Cable Hogue
# Processsing record 2654 | In Cold Blood
# Processsing record 2655 | The Nun's Story
# Processsing record 2656 | Harper
# Processsing record 2657 | Frenzy
# Processsing record 2658 | The Witch
# Processsing record 2659 | She's the One
# Processsing record 2660 | Gods and Monsters
# Processsing record 2661 | Evil Dead II
# Processsing record 2662 | Winter Passing
# Processsing record 2663 | High Anxiety
# Processsing record 2664 | Margin Call
# Processsing record 2665 | Choke
# Processsing record 2666 | Whiplash
# Processsing record 2667 | City of God
# Processsing record 2668 | Human Traffic
# Processsing record 2669 | The Hunt
# Processsing record 2670 | The Opposite Sex
# Processsing record 2671 | Dreaming of Joseph Lees
# Processsing record 2672 | Rosemary's Baby
# Processsing record 2673 | The Man Who Shot Liberty Valance
# Processsing record 2674 | Beginners
# Processsing record 2675 | It's a Wonderful Life
# Processsing record 2676 | Trainspotting
# Processsing record 2677 | Bowling for Columbine
# Processsing record 2678 | A Room with a View
# Processsing record 2679 | Martin Lawrence Live: Runteldat
# Processsing record 2680 | Cat on a Hot Tin Roof
# Processsing record 2681 | Beneath the Planet of the Apes
# Processsing record 2682 | Air Bud
# Processsing record 2683 | Friday the 13th Part VI: Jason Lives
# Processsing record 2684 | The Bridge on the River Kwai
# Processsing record 2685 | Spaced Invaders
# Processsing record 2686 | Family Plot
# Processsing record 2687 | The Apartment
# Processsing record 2688 | Jason Goes to Hell: The Final Friday
# Processsing record 2689 | Torn Curtain
# Processsing record 2690 | Dave Chappelle's Block Party
# Processsing record 2691 | Elmer Gantry
# Processsing record 2692 | Judgment at Nuremberg
# Processsing record 2693 | Red River
# Processsing record 2694 | Before Midnight
# Processsing record 2695 | Phantasm II
# Processsing record 2696 | Woman Thou Art Loosed
# Processsing record 2697 | East Is East
# Processsing record 2698 | Kama Sutra - A Tale of Love
# Processsing record 2699 | Willy Wonka & the Chocolate Factory
# Processsing record 2700 | Jawbreaker
# Processsing record 2701 | Tsotsi
# Processsing record 2702 | Happiness
# Processsing record 2703 | Tusk
# Processsing record 2704 | Oldboy
# Processsing record 2705 | Hobo with a Shotgun
# Processsing record 2706 | Fish Tank
# Processsing record 2707 | Bachelorette
# Processsing record 2708 | The Divide
# Processsing record 2709 | Point Blank
# Processsing record 2710 | Central Station
# Processsing record 2711 | Pocketful of Miracles
# Processsing record 2712 | Freakonomics
# Processsing record 2713 | Some Like It Hot
# Processsing record 2714 | Friday the 13th Part VII: The New Blood
# Processsing record 2715 | The Wizard of Oz
# Processsing record 2716 | Diary of the Dead
# Processsing record 2717 | The Black Stallion
# Processsing record 2718 | Donovan's Reef
# Processsing record 2719 | Friday the 13th: The Final Chapter
# Processsing record 2720 | Ida
# Processsing record 2721 | Riding Giants
# Processsing record 2722 | Timecrimes
# Processsing record 2723 | Singin' in the Rain
# Processsing record 2724 | 2016: Obama's America
# Processsing record 2725 | Halloween III: Season of the Witch
# Processsing record 2726 | Escape from the Planet of the Apes
# Processsing record 2727 | Hud
# Processsing record 2728 | Garden State
# Processsing record 2729 | Before Sunrise
# Processsing record 2730 | Robot & Frank
# Processsing record 2731 | The Spectacular Now
# Processsing record 2732 | Eye of the Dolphin
# Processsing record 2733 | Sleep Dealer
# Processsing record 2734 | Super
# Processsing record 2735 | Get on the Bus
# Processsing record 2736 | Idiocracy
# Processsing record 2737 | This Is England
# Processsing record 2738 | Bathing Beauty
# Processsing record 2739 | Show Boat
# Processsing record 2740 | Friday the 13th Part III
# Processsing record 2741 | The Best Years of Our Lives
# Processsing record 2742 | Mi America
# Processsing record 2743 | Sleeper
# Processsing record 2744 | It Follows
# Processsing record 2745 | Everything You Always Wanted to Know About Sex *But Were Afraid to Ask
# Processsing record 2746 | To Kill a Mockingbird
# Processsing record 2747 | Mad Max 2: The Road Warrior
# Processsing record 2748 | Boys Don't Cry
# Processsing record 2749 | Silent House
# Processsing record 2750 | The Hustler
# Processsing record 2751 | Before Sunset
# Processsing record 2752 | Amores perros
# Processsing record 2753 | Thirteen
# Processsing record 2754 | Gentleman's Agreement
# Processsing record 2755 | Winter's Bone
# Processsing record 2756 | Alexander's Ragtime Band
# Processsing record 2757 | Inside Job
# Processsing record 2758 | We Are Your Friends
# Processsing record 2759 | Harsh Times
# Processsing record 2760 | Captive
# Processsing record 2761 | Full Frontal
# Processsing record 2762 | Shortbus
# Processsing record 2763 | Waltz with Bashir
# Processsing record 2764 | The Book of Mormon Movie, Volume 1: The Journey
# Processsing record 2765 | No End in Sight
# Processsing record 2766 | The Diary of a Teenage Girl
# Processsing record 2767 | Inside Deep Throat
# Processsing record 2768 | The Virginity Hit
# Processsing record 2769 | Subway
# Processsing record 2770 | Six-String Samurai
# Processsing record 2771 | It's All Gone Pete Tong
# Processsing record 2772 | Saint John of Las Vegas
# Processsing record 2773 | Stonewall
# Processsing record 2774 | Roadside Romeo
# Processsing record 2775 | Stitches
# Processsing record 2776 | Bananas
# Processsing record 2777 | Buried
# Processsing record 2778 | A Streetcar Named Desire
# Processsing record 2779 | Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Processsing record 2780 | Beasts of the Southern Wild
# Processsing record 2781 | Battle for the Planet of the Apes
# Processsing record 2782 | Higher Ground
# Processsing record 2783 | Hang 'em High
# Processsing record 2784 | Run Lola Run
# Processsing record 2785 | May
# Processsing record 2786 | Conquest of the Planet of the Apes
# Processsing record 2787 | I Spit on Your Grave
# Processsing record 2788 | Happy, Texas
# Processsing record 2789 | The Lunchbox
# Processsing record 2790 | You Can't Take It With You
# Processsing record 2791 | She Wore a Yellow Ribbon
# Processsing record 2792 | The Conversation
# Processsing record 2793 | Waitress
# Processsing record 2794 | Bloodsport
# Processsing record 2795 | Mr. Smith Goes to Washington
# Processsing record 2796 | Kids
# Processsing record 2797 | The Squid and the Whale
# Processsing record 2798 | Kissing Jessica Stein
# Processsing record 2799 | Spellbound
# Processsing record 2800 | Buffalo '66
# Processsing record 2801 | Repo Man
# Processsing record 2802 | The Ballad of Jack and Rose
# Processsing record 2803 | The To Do List
# Processsing record 2804 | Killing Zoe
# Processsing record 2805 | The Believer
# Processsing record 2806 | Session 9
# Processsing record 2807 | My Name Is Bruce
# Processsing record 2808 | Pontypool
# Processsing record 2809 | The Lords of Salem
# Processsing record 2810 | Shalako
# Processsing record 2811 | Lock, Stock and Two Smoking Barrels
# Processsing record 2812 | Journey from the Fall
# Processsing record 2813 | Rebecca
# Processsing record 2814 | The Lost Weekend
# Processsing record 2815 | C.H.U.D.
# Processsing record 2816 | Niagara
# Processsing record 2817 | How Green Was My Valley
# Processsing record 2818 | Super Troopers
# Processsing record 2819 | The Trouble with Harry
# Processsing record 2820 | Home Run
# Processsing record 2821 | Reservoir Dogs
# Processsing record 2822 | The Good, the Bad and the Ugly
# Processsing record 2823 | Pink Ribbons, Inc.
# Processsing record 2824 | The Charge of the Light Brigade
# Processsing record 2825 | Airborne
# Processsing record 2826 | Waiting...
# Processsing record 2827 | Casablanca
# Processsing record 2828 | Hellraiser
# Processsing record 2829 | God's Not Dead 2
# Processsing record 2830 | Cry_Wolf
# Processsing record 2831 | Blue Valentine
# Processsing record 2832 | Transamerica
# Processsing record 2833 | Love Me Tender
# Processsing record 2834 | Sands of Iwo Jima
# Processsing record 2835 | The Green Inferno
# Processsing record 2836 | The Sessions
# Processsing record 2837 | Two Girls and a Guy
# Processsing record 2838 | Who Killed the Electric Car?
# Processsing record 2839 | The Broken Hearts Club: A Romantic Comedy
# Processsing record 2840 | Brigham City
# Processsing record 2841 | Blue Car
# Processsing record 2842 | The Act of Killing
# Processsing record 2843 | Alone With Her
# Processsing record 2844 | Special
# Processsing record 2845 | Charly
# Processsing record 2846 | On the Waterfront
# Processsing record 2847 | L!fe Happens
# Processsing record 2848 | 4 Months, 3 Weeks and 2 Days
# Processsing record 2849 | Hard Candy
# Processsing record 2850 | The Quiet
# Processsing record 2851 | Latter Days
# Processsing record 2852 | For a Good Time, Call...
# Processsing record 2853 | Ruby in Paradise
# Processsing record 2854 | Raising Victor Vargas
# Processsing record 2855 | The Mudge Boy
# Processsing record 2856 | Dead Snow
# Processsing record 2857 | Safety Not Guaranteed
# Processsing record 2858 | Kill List
# Processsing record 2859 | The Innkeepers
# Processsing record 2860 | High Noon
# Processsing record 2861 | Hoop Dreams
# Processsing record 2862 | L.I.E.
# Processsing record 2863 | Half Nelson
# Processsing record 2864 | Beyond the Mat
# Processsing record 2865 | Mean Creek
# Processsing record 2866 | Rubber
# Processsing record 2867 | Monsters
# Processsing record 2868 | Conversations with Other Women
# Processsing record 2869 | 42nd Street
# Processsing record 2870 | Monty Python and the Holy Grail
# Processsing record 2871 | What Happens in Vegas
# Processsing record 2872 | My Beautiful Laundrette
# Processsing record 2873 | The Broadway Melody
# Processsing record 2874 | Murderball
# Processsing record 2875 | 12 Angry Men
# Processsing record 2876 | It Happened One Night
# Processsing record 2877 | Tumbleweeds
# Processsing record 2878 | The Prophecy
# Processsing record 2879 | Ayurveda: Art of Being
# Processsing record 2880 | First Love, Last Rites
# Processsing record 2881 | Cube
# Processsing record 2882 | I Married a Strange Person!
# Processsing record 2883 | Like Crazy
# Processsing record 2884 | The Canyons
# Processsing record 2885 | Bronson
# Processsing record 2886 | Burn
# Processsing record 2887 | She Done Him Wrong
# Processsing record 2888 | The Grace Card
# Processsing record 2889 | Children of Heaven
# Processsing record 2890 | The Birth of a Nation
# Processsing record 2891 | Tiny Furniture
# Processsing record 2892 | The Signal
# Processsing record 2893 | Down Terrace
# Processsing record 2894 | Cure
# Processsing record 2895 | El Mariachi

# %%
df_plot_movie = pd.DataFrame(list(zip(movie_name,plot)), columns = ['movie','plot'])

# %%
#send to excell
df_plot_movie.to_csv('movie_plot.csv')

# %%
df_movie_plot = pd.read_csv(os.path.join('movie_plot_with_polarity.csv'))
df_movie_plot.head()
#this imports another graph that creates a polrity column if the RB and RT polarity are below or above the medium.
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                     title.1     budget     revenue   RB Ratio  \
# 0                                    Avatar  237000000  2787965087  11.763566
# 1  Pirates of the Caribbean: At World's End  300000000   961000000   3.203333
# 2                                   Spectre  245000000   880674609   3.594590
# 3                     The Dark Knight Rises  250000000  1084939099   4.339756
# 4                               John Carter  260000000   284139100   1.092843
#
#    RT Score  RB polarity  RT polarity  \
# 0      0.82            1            1
# 1      0.44            1            0
# 2      0.63            1            1
# 3      0.87            1            1
# 4      0.52            0            0
#
#                                       movie  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 plot
# 0  A paraplegic Marine dispatched to the moon Pan...
# 1  Captain Barbossa, Will Turner and Elizabeth Sw...
# 2  A cryptic message from James Bond's past sends...
# 3  Eight years after the Joker's reign of anarchy...
# 4  Transported to Barsoom, a Civil War vet discov...

# %%
from nltk import tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import string

### sklearn
from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix, accuracy_score

### numpy for seed.  Good practice for reproducibility, not something we touched on but worth wild to look further.
import numpy as np
from numpy import random

SEED = 1234

random.seed(SEED)

# %%
### Define simple space tokenizer
translator = str.maketrans('', '', string.punctuation)
tk = tokenize.simple.SpaceTokenizer()

def simple_tokenizer(x):
    x = x.translate(translator).strip().lower()
    return tk.tokenize(x)

### Quick look at what the tokenizer produces
print(df_movie_plot['plot'].head().apply(lambda x : simple_tokenizer(x)))

### Developing the corpus or list of sentences for processing later
corpus = df_movie_plot['plot'].tolist()
corpus[0:5]
# Out:
# 0    [a, paraplegic, marine, dispatched, to, the, m...
# 1    [captain, barbossa, will, turner, and, elizabe...
# 2    [a, cryptic, message, from, james, bonds, past...
# 3    [eight, years, after, the, jokers, reign, of, ...
# 4    [transported, to, barsoom, a, civil, war, vet,...
# Name: plot, dtype: object
# ['A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#  'Captain Barbossa, Will Turner and Elizabeth Swann must sail off the edge of the map, navigate treachery and betrayal, find Jack Sparrow, and make their final alliances for one last decisive battle.',
#  "A cryptic message from James Bond's past sends him on a trail to uncover the exsistence of a sinister organisation named SPECTRE. With a new threat dawning, Bond learns the terrible truth about the author of all his pain in his most recent missions.",
#  "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.",
#  'Transported to Barsoom, a Civil War vet discovers a barren planet seemingly inhabited by 12-foot tall barbarians. Finding himself prisoner of these creatures, he escapes, only to encounter Woola and a princess in desperate need of a savior.']

# %%
# find polarity of critic score with plot
vectorizer = TfidfVectorizer(tokenizer=simple_tokenizer, stop_words='english')
tf = vectorizer.fit(corpus)
X = tf.transform(corpus)

### Combining result of TFIDF with `target` columns
full_df = pd.concat([pd.DataFrame(X.toarray()), df_movie_plot['RT polarity']], axis=1)
print("Vector features : ", vectorizer.get_feature_names()[0:20])
print("Vector shape/size : ",X.shape)
# Out:
# Vector features :  ['', '00', '007', '10', '100000', '1000000', '11', '119', '11th', '11yearold', '12', '1206', '12foot', '12th', '13', '14', '1408', '142', '14yearold', '15']
# Vector shape/size :  (2895, 10728)

# %%
target_col = 'RT polarity'
y=df_movie_plot[target_col]
X_train, X_test, y_train, y_test = train_test_split(full_df.drop(target_col, axis=1)
                                                    ,y, test_size=0.20, random_state=SEED)
print(X_train.shape, y_train.shape)
# Out:
# (2316, 10728) (2316,)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues,
                          include_cm=False,
                          fig_size=(10, 8)):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    from sklearn.utils.multiclass import unique_labels
    
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    if include_cm:
        print(cm)

    fig, ax = plt.subplots(figsize=fig_size)
    ax.grid(False)
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
clf = MultinomialNB().fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[188,  97],
#        [135, 159]], dtype=int64)

# %%
print("Accuracy of base model is {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy of base model is 59.93 %

# %%
class_names = ['Above', 'Below']
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Confusion matrix, with normalization', fig_size=(10, 8));
#again high persentage of false negatives and positives.

# %%
plot = "T'Challa, heir to the hidden but advanced kingdom of Wakanda, must step forward to lead his people into a new future and must confront a challenger from his country's past."
### Transform Review
review_transformed = tf.transform([plot])

### Make Prediction
pred = clf.predict(review_transformed)

### Using the defined `class_names` get the predicted Polarity ( negative/positive )
print("The Reviews will be {} the medium".format(class_names[pred[0]]))
# Out:
# The Reviews will be Above the medium
